# %% [markdown]
# ## Poročilo vaja 3.3
# #### Preverjanje hipotez po članku: Anketa za nogometne trenerje
#
# Imamo podatke ankete"**Anketa za nogometne trenerje**": *anketa_precisceni 26 12 nogomet trenerji.sav*.
#
# Zanima nas odziv nogometnih trenerjev glede na stopnjo izobrazbe.
# 1. Razdelite trenerje v dve skupini glede na izobrazbo: srednješolsko ali manj in višješolsko ali več (Q41).
# 2. Izvedite naslednje analize glede na ti dve skupini:
#    - Ali obstajajo razlike med skupinama v mnenju, kateri dejavniki so pomembni za trenerski poklic? (Q22)
#    - Kako ocenjujejo zadovoljstvo? (Q23, Q34)
#    - Kaj so glavni problemi pri delu v vašem klubu? (Q32)
# 3. Podobno analizo ponovite, če razdelite trenerje glede na področja izobrazbe trenerjev na dve skupini (Q42): športno področje izobrazbe proti ostalim področjem.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from scipy.stats import mannwhitneyu

# %%
pd.set_option('display.max_rows', None)

# %%
path = os.getcwd()
df = pd.read_excel(path + '\\data\\anketa114621-2024-03-04.xlsx')
df.head()
# Out:
#                                                   Q1  \
# 0  Koliko ur na teden delate kot trener (s svojo ...
# 1                                                  9
# 2                                                 12
# 3                                                  6
# 4                                                  6
#
#                                  Q2  \
# 0  Koliko let že delate kot trener?
# 1                                15
# 2                                10
# 3                                16
# 4                                 3
#
#                                                   Q3  \
# 0  Koliko let že delate kot trener v trenutnem kl...
# 1                                                 15
# 2                                                  3
# 3                                                  8
# 4                                                  3
#
#                                          Q4  \
# 0  Kakšna je vaša trenerska usposboljenost?
# 1                                         2
# 2                                         4
# 3                                         2
# 4                                         1
#
#                                                   Q5  \
# 0  Kakšne je vaša trenutna trenerska licenca (sez...
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  1
#
#                                                   Q6  \
# 0  Koliko dni na teden ste na nogometnem igrišču ...
# 1                                                  4
# 2                                                  6
# 3                                                  5
# 4                                                  4
#
#                                                   Q7  \
# 0  Koliko ur na teden preživite v nogometnem klub...
# 1                                                 20
# 2                                                 15
# 3                                                 11
# 4                                                  8
#
#                                                   Q8  \
# 0  Koliko ur od tega je namenjeno na teden  za pr...
# 1                                                 10
# 2                                                 12
# 3                                                  7
# 4                                                  6
#
#                                                   Q9  \
# 0  Koliko ur na teden delate doma za svojo ekipo ...
# 1                                                  3
# 2                                                  5
# 3                                                  5
# 4                                                  2
#
#                                                  Q10  ...  \
# 0  Ocenite koliko ur na teden porabite za pridobi...  ...
# 1                                                  1  ...
# 2                                                  1  ...
# 3                                                  4  ...
# 4                                                  1  ...
#
#                                                Q39       Q40 Q40_3_text  \
# 0  Član katerega društva nogemetnih trenerjev ste?  Vaš spol     Drugo:
# 1                                                5         2         -2
# 2                                               -3        -3         -3
# 3                                                5         2         -2
# 4                                                5         2         -2
#
#                                        Q41  \
# 0  Kaj je vaša najvišja stopnja izobrazbe?
# 1                                        4
# 2                                       -3
# 3                                        2
# 4                                        4
#
#                                                  Q42  Q42_13_text  \
# 0  Na katerem področju ste pridobili to diplomo? ...       Drugo:
# 1                                                  3           -2
# 2                                                 -3           -3
# 3                                                 -1           -1
# 4                                                 13  Strojništvo
#
#                                   Q43 Q43_4_text                       Q44  \
# 0  Kakšen je vaš zaposlitveni status?     Drugo:  Ali ste redno zaposleni?
# 1                                   3         -2                         2
# 2                                  -3         -3                        -3
# 3                                   2         -2                         2
# 4                                   1         -2                         3
#
#   Q44_3_text
# 0     Drugo:
# 1         -2
# 2         -3
# 3         -2
# 4         -1
#
# [5 rows x 253 columns]

# %%
# assign the 0th row to questions variable and remove it
questions = df.iloc[0]
df.drop([0], inplace=True)

# %% [markdown]
# #### 1. Razdelite trenerje v dve skupini.
#
# Trenerje smo razdelili najprej na dve skupini glede izobrazbe (srednješolsko ali manj in višješolsko ali več) in nato še glede področja izobrazbe (športno treniranje in drugo).

# %%
# create binomial variables: education (high-school or lower/ higher than high-school)
#                            field (sports / other)
df['education'] = np.where(df['Q41'].isin([1, 2]), 'srednja šola ali manj', np.where(df['Q41'].isin([3, 4]), 'višješolska ali več', pd.NA))
df['field'] = np.where(df['Q42'].isin([11]), 'športna izobrazba', np.where(df['Q42'] > 0, 'drugo', pd.NA))

df_education = df.dropna(subset=['education']).copy()
df_field = df.dropna(subset=['field']).copy()

# %% [markdown]
# #### 2. Izvedite naslednje analize glede na ti dve skupini
# **Metodologija:** V analizi primerjamo ali obstajajo razlike med skupinama v mnenju, kateri dejavniki so pomembni za trenerski poklic, kako ocenjujejo zadovoljstvo in kaj je glavni problem pri delu. Anketiranci so na zastavljena vprašanja odgovarjali s pomočjo odgovorov 5 stopenjske Likertove lestvice. Takšni podatki so ordinalni, zato za analizo uporabimo neparametričen test; *Mann-Withney U* test.

# %%
def mann_whitney_results(data, variable, var_condition, filt):
    """
    Calculates the Mann-Whitney U test on non-normally distributed data 
    :param data: pd.DataFrame containing the data
    :param variable: group by the variable
    :param var_condition: group condition
    :param filt: by what substring to filter subquestion labels. E.g. Q22a, Q22b --> filter = Q22
    :return: returns pd.DataFrame of the results
    """
    
    results = []
    
    data_filtered = data.filter(regex=filt)
    
    columns = data_filtered.columns
    
    
    for c in columns:
        gr_less = data[data[variable] == var_condition]
        gr_more = data[data[variable] != var_condition]
        
        gr_less = gr_less[gr_less[c] >= 1][c].astype(np.int64)
        gr_more = gr_more[gr_more[c] >= 1][c].astype(np.int64)
        
        stat, p = mannwhitneyu(gr_less, gr_more)
        results.append({
            'Statement': f'{c}: {questions[c]}',
            'U statistic': round(stat, 2),
            'p-value': round(p, 2)
        })
    return pd.DataFrame(results)

# %%
q22_table_ed = mann_whitney_results(data=df_education, variable='education', var_condition='srednja šola ali manj', filt='Q22')

display(
    q22_table_ed.style
    .set_caption('Q22: Kako pomembne so z ozirom na Vašo predstavo o trenerskem poklicu naslednji dejavniki? Razlika v stopnji izobrazbe')
    .format({col: "{:.2f}" for col in q22_table_ed.select_dtypes(include='number').columns})
    .set_table_styles([
              {'selector': 'caption', 'props': [('font-size', '16px'), 
                                                ('font-weight', 'bold'), 
                                                ('border-bottom', '1px solid black'),
                                                ('width', '100%')]},
              {'selector': 'td', 'props': 'text-align: left;'}
          ])\
          .hide())
# Out:
# <style type="text/css">
# #T_acd94 caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# #T_acd94 td {
#   text-align: left;
# }
# </style>
# <table id="T_acd94">
#   <caption>Q22: Kako pomembne so z ozirom na Vašo predstavo o trenerskem poklicu naslednji dejavniki? Razlika v stopnji izobrazbe</caption>
#   <thead>
#     <tr>
#       <th id="T_acd94_level0_col0" class="col_heading level0 col0" >Statement</th>
#       <th id="T_acd94_level0_col1" class="col_heading level0 col1" >U statistic</th>
#       <th id="T_acd94_level0_col2" class="col_heading level0 col2" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_acd94_row0_col0" class="data row0 col0" >Q22a: Dobri medsebojni odnosi z igralci/igralkami</td>
#       <td id="T_acd94_row0_col1" class="data row0 col1" >34612.50</td>
#       <td id="T_acd94_row0_col2" class="data row0 col2" >0.16</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row1_col0" class="data row1 col0" >Q22b: Dobri medsebojni odnosi med trenerji</td>
#       <td id="T_acd94_row1_col1" class="data row1 col1" >34475.00</td>
#       <td id="T_acd94_row1_col2" class="data row1 col2" >0.25</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row2_col0" class="data row2 col0" >Q22c: Dobri medsebojni odnosi z vodstvom kluba</td>
#       <td id="T_acd94_row2_col1" class="data row2 col1" >34274.00</td>
#       <td id="T_acd94_row2_col2" class="data row2 col2" >0.29</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row3_col0" class="data row3 col0" >Q22d: Izpolnjevanje vizije kluba</td>
#       <td id="T_acd94_row3_col1" class="data row3 col1" >33920.00</td>
#       <td id="T_acd94_row3_col2" class="data row3 col2" >0.37</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row4_col0" class="data row4 col0" >Q22e: Finančna stabilnost kluba</td>
#       <td id="T_acd94_row4_col1" class="data row4 col1" >32219.00</td>
#       <td id="T_acd94_row4_col2" class="data row4 col2" >0.79</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row5_col0" class="data row5 col0" >Q22f: Organiziranost kluba</td>
#       <td id="T_acd94_row5_col1" class="data row5 col1" >33213.50</td>
#       <td id="T_acd94_row5_col2" class="data row5 col2" >0.63</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row6_col0" class="data row6 col0" >Q22g: Možnost napredovanja</td>
#       <td id="T_acd94_row6_col1" class="data row6 col1" >35983.00</td>
#       <td id="T_acd94_row6_col2" class="data row6 col2" >0.03</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row7_col0" class="data row7 col0" >Q22h: Strokovna usposobljenost</td>
#       <td id="T_acd94_row7_col1" class="data row7 col1" >32301.50</td>
#       <td id="T_acd94_row7_col2" class="data row7 col2" >0.77</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row8_col0" class="data row8 col0" >Q22i: Časovna fleksibilnost</td>
#       <td id="T_acd94_row8_col1" class="data row8 col1" >34596.50</td>
#       <td id="T_acd94_row8_col2" class="data row8 col2" >0.17</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row9_col0" class="data row9 col0" >Q22j: Predhodne izkušnje in dosežki</td>
#       <td id="T_acd94_row9_col1" class="data row9 col1" >34608.00</td>
#       <td id="T_acd94_row9_col2" class="data row9 col2" >0.23</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row10_col0" class="data row10 col0" >Q22k: Prepoznavnost v družbi</td>
#       <td id="T_acd94_row10_col1" class="data row10 col1" >36125.50</td>
#       <td id="T_acd94_row10_col2" class="data row10 col2" >0.03</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row11_col0" class="data row11 col0" >Q22l: visok dohodek</td>
#       <td id="T_acd94_row11_col1" class="data row11 col1" >32536.00</td>
#       <td id="T_acd94_row11_col2" class="data row11 col2" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row12_col0" class="data row12 col0" >Q22m: veselje do poklica</td>
#       <td id="T_acd94_row12_col1" class="data row12 col1" >32682.00</td>
#       <td id="T_acd94_row12_col2" class="data row12 col2" >0.88</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row13_col0" class="data row13 col0" >Q22n: aktivno se sam oz. sem se ukvarjal z nogometom</td>
#       <td id="T_acd94_row13_col1" class="data row13 col1" >34383.50</td>
#       <td id="T_acd94_row13_col2" class="data row13 col2" >0.28</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row14_col0" class="data row14 col0" >Q22o: igralce naučiti nogometa</td>
#       <td id="T_acd94_row14_col1" class="data row14 col1" >32704.50</td>
#       <td id="T_acd94_row14_col2" class="data row14 col2" >0.93</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row15_col0" class="data row15 col0" >Q22p: ustvariti dobrega igralca</td>
#       <td id="T_acd94_row15_col1" class="data row15 col1" >35299.50</td>
#       <td id="T_acd94_row15_col2" class="data row15 col2" >0.07</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row16_col0" class="data row16 col0" >Q22q: Dobro vzdušje v ekipi</td>
#       <td id="T_acd94_row16_col1" class="data row16 col1" >34545.00</td>
#       <td id="T_acd94_row16_col2" class="data row16 col2" >0.14</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row17_col0" class="data row17 col0" >Q22r: Visok ugled v družbi</td>
#       <td id="T_acd94_row17_col1" class="data row17 col1" >34071.00</td>
#       <td id="T_acd94_row17_col2" class="data row17 col2" >0.35</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row18_col0" class="data row18 col0" >Q22s: odločanje o samem sebi</td>
#       <td id="T_acd94_row18_col1" class="data row18 col1" >35202.00</td>
#       <td id="T_acd94_row18_col2" class="data row18 col2" >0.10</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row19_col0" class="data row19 col0" >Q22t: Odnos z navijači</td>
#       <td id="T_acd94_row19_col1" class="data row19 col1" >36600.50</td>
#       <td id="T_acd94_row19_col2" class="data row19 col2" >0.01</td>
#     </tr>
#     <tr>
#       <td id="T_acd94_row20_col0" class="data row20 col0" >Q22u: Odnos z mediji</td>
#       <td id="T_acd94_row20_col1" class="data row20 col1" >34510.50</td>
#       <td id="T_acd94_row20_col2" class="data row20 col2" >0.24</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Interpretacija:** Iz rezultatov Mann-Whitney U testa lahko vidimo, da se odgovor skupine z višjo in skupine z nižjo izobrazbo statistično značilno razlikujejo v primerih trditve ***Q22g, Q22k, in Q22t***. To pomeni, da se mnenja o možnosti napredovanja, prepoznavnosti v družbi in odnosu z navijači kot pomembnemu dejavniku za predstavo o trenerskem poklicu med skupinama statistično značilno razlikujejo.

# %%
q22_table_fi = mann_whitney_results(data=df_field, variable='field', var_condition='športna izobrazba', filt='Q22')

display(
    q22_table_fi.style
    .set_caption('Q22: Kako pomembne so z ozirom na Vašo predstavo o trenerskem poklicu naslednji dejavniki? Razlika v področju izobrazbe')\
    .format({col: "{:.2f}" for col in q22_table_fi.select_dtypes(include='number').columns})
    .set_table_styles([
              {'selector': 'caption', 'props': [('font-size', '16px'), 
                                                ('font-weight', 'bold'), 
                                                ('border-bottom', '1px solid black'),
                                                ('width', '100%')]},
              {'selector': 'td', 'props': 'text-align: left;'}
          ])\
          .hide())
# Out:
# <style type="text/css">
# #T_2812e caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# #T_2812e td {
#   text-align: left;
# }
# </style>
# <table id="T_2812e">
#   <caption>Q22: Kako pomembne so z ozirom na Vašo predstavo o trenerskem poklicu naslednji dejavniki? Razlika v področju izobrazbe</caption>
#   <thead>
#     <tr>
#       <th id="T_2812e_level0_col0" class="col_heading level0 col0" >Statement</th>
#       <th id="T_2812e_level0_col1" class="col_heading level0 col1" >U statistic</th>
#       <th id="T_2812e_level0_col2" class="col_heading level0 col2" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2812e_row0_col0" class="data row0 col0" >Q22a: Dobri medsebojni odnosi z igralci/igralkami</td>
#       <td id="T_2812e_row0_col1" class="data row0 col1" >23913.00</td>
#       <td id="T_2812e_row0_col2" class="data row0 col2" >0.22</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row1_col0" class="data row1 col0" >Q22b: Dobri medsebojni odnosi med trenerji</td>
#       <td id="T_2812e_row1_col1" class="data row1 col1" >24704.00</td>
#       <td id="T_2812e_row1_col2" class="data row1 col2" >0.07</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row2_col0" class="data row2 col0" >Q22c: Dobri medsebojni odnosi z vodstvom kluba</td>
#       <td id="T_2812e_row2_col1" class="data row2 col1" >23350.00</td>
#       <td id="T_2812e_row2_col2" class="data row2 col2" >0.54</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row3_col0" class="data row3 col0" >Q22d: Izpolnjevanje vizije kluba</td>
#       <td id="T_2812e_row3_col1" class="data row3 col1" >23362.50</td>
#       <td id="T_2812e_row3_col2" class="data row3 col2" >0.54</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row4_col0" class="data row4 col0" >Q22e: Finančna stabilnost kluba</td>
#       <td id="T_2812e_row4_col1" class="data row4 col1" >23197.00</td>
#       <td id="T_2812e_row4_col2" class="data row4 col2" >0.63</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row5_col0" class="data row5 col0" >Q22f: Organiziranost kluba</td>
#       <td id="T_2812e_row5_col1" class="data row5 col1" >22697.00</td>
#       <td id="T_2812e_row5_col2" class="data row5 col2" >0.89</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row6_col0" class="data row6 col0" >Q22g: Možnost napredovanja</td>
#       <td id="T_2812e_row6_col1" class="data row6 col1" >23118.00</td>
#       <td id="T_2812e_row6_col2" class="data row6 col2" >0.74</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row7_col0" class="data row7 col0" >Q22h: Strokovna usposobljenost</td>
#       <td id="T_2812e_row7_col1" class="data row7 col1" >20240.00</td>
#       <td id="T_2812e_row7_col2" class="data row7 col2" >0.03</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row8_col0" class="data row8 col0" >Q22i: Časovna fleksibilnost</td>
#       <td id="T_2812e_row8_col1" class="data row8 col1" >22903.00</td>
#       <td id="T_2812e_row8_col2" class="data row8 col2" >0.83</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row9_col0" class="data row9 col0" >Q22j: Predhodne izkušnje in dosežki</td>
#       <td id="T_2812e_row9_col1" class="data row9 col1" >24329.50</td>
#       <td id="T_2812e_row9_col2" class="data row9 col2" >0.19</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row10_col0" class="data row10 col0" >Q22k: Prepoznavnost v družbi</td>
#       <td id="T_2812e_row10_col1" class="data row10 col1" >24442.50</td>
#       <td id="T_2812e_row10_col2" class="data row10 col2" >0.17</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row11_col0" class="data row11 col0" >Q22l: visok dohodek</td>
#       <td id="T_2812e_row11_col1" class="data row11 col1" >22624.00</td>
#       <td id="T_2812e_row11_col2" class="data row11 col2" >0.94</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row12_col0" class="data row12 col0" >Q22m: veselje do poklica</td>
#       <td id="T_2812e_row12_col1" class="data row12 col1" >21017.50</td>
#       <td id="T_2812e_row12_col2" class="data row12 col2" >0.06</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row13_col0" class="data row13 col0" >Q22n: aktivno se sam oz. sem se ukvarjal z nogometom</td>
#       <td id="T_2812e_row13_col1" class="data row13 col1" >24113.00</td>
#       <td id="T_2812e_row13_col2" class="data row13 col2" >0.26</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row14_col0" class="data row14 col0" >Q22o: igralce naučiti nogometa</td>
#       <td id="T_2812e_row14_col1" class="data row14 col1" >21767.00</td>
#       <td id="T_2812e_row14_col2" class="data row14 col2" >0.46</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row15_col0" class="data row15 col0" >Q22p: ustvariti dobrega igralca</td>
#       <td id="T_2812e_row15_col1" class="data row15 col1" >22103.50</td>
#       <td id="T_2812e_row15_col2" class="data row15 col2" >0.65</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row16_col0" class="data row16 col0" >Q22q: Dobro vzdušje v ekipi</td>
#       <td id="T_2812e_row16_col1" class="data row16 col1" >22124.00</td>
#       <td id="T_2812e_row16_col2" class="data row16 col2" >0.54</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row17_col0" class="data row17 col0" >Q22r: Visok ugled v družbi</td>
#       <td id="T_2812e_row17_col1" class="data row17 col1" >24548.50</td>
#       <td id="T_2812e_row17_col2" class="data row17 col2" >0.13</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row18_col0" class="data row18 col0" >Q22s: odločanje o samem sebi</td>
#       <td id="T_2812e_row18_col1" class="data row18 col1" >23330.50</td>
#       <td id="T_2812e_row18_col2" class="data row18 col2" >0.65</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row19_col0" class="data row19 col0" >Q22t: Odnos z navijači</td>
#       <td id="T_2812e_row19_col1" class="data row19 col1" >22934.00</td>
#       <td id="T_2812e_row19_col2" class="data row19 col2" >0.81</td>
#     </tr>
#     <tr>
#       <td id="T_2812e_row20_col0" class="data row20 col0" >Q22u: Odnos z mediji</td>
#       <td id="T_2812e_row20_col1" class="data row20 col1" >23454.50</td>
#       <td id="T_2812e_row20_col2" class="data row20 col2" >0.54</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Interpretacija:** Iz rezultatov Mann-Whitney U testa lahko vidimo, da se odgovori skupine s športno in skupine ne športno izobrazbo statistično značilno razlikujejo v le primeru trditve ***Q22h***. To pomeni, da se mnenje o strokovni usposobljenosti kot pomembnemu dejavniku za predstavo o trenerskem poklicu med skupinama statistično značilno razlikujejo.

# %%
q23_table_ed = mann_whitney_results(data=df_education, variable='education', var_condition='srednja šola ali manj', filt='Q23')
q34_table_ed = mann_whitney_results(data=df_education, variable='education', var_condition='srednja šola ali manj', filt='Q34')

display(
    q23_table_ed.style
        .set_caption('Q23: Biti zadovoljen s trenerskim poklicem je odvisno od več stvari. Kako ocenjujete naslednje vidike in pogoje vaše poklicne usmeritve? Razlika v stopnji izobrazbe')\
        .format({col: "{:.2f}" for col in q23_table_ed.select_dtypes(include='number').columns})
        .set_table_styles([
              {'selector': 'caption', 'props': [('font-size', '16px'), 
                                                ('font-weight', 'bold'), 
                                                ('border-bottom', '1px solid black'),
                                                ('width', '100%')]},
              {'selector': 'td', 'props': 'text-align: left;'}
          ])\
          .hide())
display(
    q34_table_ed.style
        .set_caption('Q34: Ocenite dejavnike, ki so za vas pomembni za zadovoljstvo pri delu. Razlika v stopnji izobrazbe')
        .format({col: "{:.2f}" for col in q34_table_ed.select_dtypes(include='number').columns})
        .set_table_styles([
              {'selector': 'caption', 'props': [('font-size', '16px'), 
                                                ('font-weight', 'bold'), 
                                                ('border-bottom', '1px solid black'),
                                                ('width', '100%')]},
              {'selector': 'td', 'props': 'text-align: left;'}
          ])\
          .hide())
# Out:
# <style type="text/css">
# #T_259c0 caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# #T_259c0 td {
#   text-align: left;
# }
# </style>
# <table id="T_259c0">
#   <caption>Q23: Biti zadovoljen s trenerskim poklicem je odvisno od več stvari. Kako ocenjujete naslednje vidike in pogoje vaše poklicne usmeritve? Razlika v stopnji izobrazbe</caption>
#   <thead>
#     <tr>
#       <th id="T_259c0_level0_col0" class="col_heading level0 col0" >Statement</th>
#       <th id="T_259c0_level0_col1" class="col_heading level0 col1" >U statistic</th>
#       <th id="T_259c0_level0_col2" class="col_heading level0 col2" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_259c0_row0_col0" class="data row0 col0" >Q23a: uresničevanje svojih idej v praksi</td>
#       <td id="T_259c0_row0_col1" class="data row0 col1" >32595.00</td>
#       <td id="T_259c0_row0_col2" class="data row0 col2" >0.93</td>
#     </tr>
#     <tr>
#       <td id="T_259c0_row1_col0" class="data row1 col0" >Q23b: možnost raznovrstnega treniranja</td>
#       <td id="T_259c0_row1_col1" class="data row1 col1" >31360.00</td>
#       <td id="T_259c0_row1_col2" class="data row1 col2" >0.34</td>
#     </tr>
#     <tr>
#       <td id="T_259c0_row2_col0" class="data row2 col0" >Q23c: pogoji za trening in tekmovanje</td>
#       <td id="T_259c0_row2_col1" class="data row2 col1" >33759.00</td>
#       <td id="T_259c0_row2_col2" class="data row2 col2" >0.45</td>
#     </tr>
#     <tr>
#       <td id="T_259c0_row3_col0" class="data row3 col0" >Q23d: stiki z drugimi strokovnjaki</td>
#       <td id="T_259c0_row3_col1" class="data row3 col1" >31558.00</td>
#       <td id="T_259c0_row3_col2" class="data row3 col2" >0.42</td>
#     </tr>
#     <tr>
#       <td id="T_259c0_row4_col0" class="data row4 col0" >Q23e: ustvarjalno delo</td>
#       <td id="T_259c0_row4_col1" class="data row4 col1" >32185.50</td>
#       <td id="T_259c0_row4_col2" class="data row4 col2" >0.71</td>
#     </tr>
#     <tr>
#       <td id="T_259c0_row5_col0" class="data row5 col0" >Q23f: rezultatski uspehi</td>
#       <td id="T_259c0_row5_col1" class="data row5 col1" >35278.00</td>
#       <td id="T_259c0_row5_col2" class="data row5 col2" >0.11</td>
#     </tr>
#     <tr>
#       <td id="T_259c0_row6_col0" class="data row6 col0" >Q23g: napredek mladih nogometašev</td>
#       <td id="T_259c0_row6_col1" class="data row6 col1" >32951.00</td>
#       <td id="T_259c0_row6_col2" class="data row6 col2" >0.86</td>
#     </tr>
#     <tr>
#       <td id="T_259c0_row7_col0" class="data row7 col0" >Q23h: podpora vodstvenih struktur v klubu</td>
#       <td id="T_259c0_row7_col1" class="data row7 col1" >32312.00</td>
#       <td id="T_259c0_row7_col2" class="data row7 col2" >0.71</td>
#     </tr>
#     <tr>
#       <td id="T_259c0_row8_col0" class="data row8 col0" >Q23i: Podpora vodilnih na NZS</td>
#       <td id="T_259c0_row8_col1" class="data row8 col1" >36857.50</td>
#       <td id="T_259c0_row8_col2" class="data row8 col2" >0.01</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_12766 caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# #T_12766 td {
#   text-align: left;
# }
# </style>
# <table id="T_12766">
#   <caption>Q34: Ocenite dejavnike, ki so za vas pomembni za zadovoljstvo pri delu. Razlika v stopnji izobrazbe</caption>
#   <thead>
#     <tr>
#       <th id="T_12766_level0_col0" class="col_heading level0 col0" >Statement</th>
#       <th id="T_12766_level0_col1" class="col_heading level0 col1" >U statistic</th>
#       <th id="T_12766_level0_col2" class="col_heading level0 col2" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_12766_row0_col0" class="data row0 col0" >Q34a: Pogoji dela</td>
#       <td id="T_12766_row0_col1" class="data row0 col1" >34127.00</td>
#       <td id="T_12766_row0_col2" class="data row0 col2" >0.25</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row1_col0" class="data row1 col0" >Q34b: Redno plačilo za opravljeno delo</td>
#       <td id="T_12766_row1_col1" class="data row1 col1" >31578.50</td>
#       <td id="T_12766_row1_col2" class="data row1 col2" >0.61</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row2_col0" class="data row2 col0" >Q34c: Možnosti napredovanja</td>
#       <td id="T_12766_row2_col1" class="data row2 col1" >32869.00</td>
#       <td id="T_12766_row2_col2" class="data row2 col2" >0.65</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row3_col0" class="data row3 col0" >Q34d: Nenehno dokazovanje</td>
#       <td id="T_12766_row3_col1" class="data row3 col1" >37096.50</td>
#       <td id="T_12766_row3_col2" class="data row3 col2" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row4_col0" class="data row4 col0" >Q34e: Količina stresa pri delu</td>
#       <td id="T_12766_row4_col1" class="data row4 col1" >30524.00</td>
#       <td id="T_12766_row4_col2" class="data row4 col2" >0.31</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row5_col0" class="data row5 col0" >Q34f: Spoštovanje</td>
#       <td id="T_12766_row5_col1" class="data row5 col1" >33702.50</td>
#       <td id="T_12766_row5_col2" class="data row5 col2" >0.40</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row6_col0" class="data row6 col0" >Q34g: Priznavanje znanja, izkušenj</td>
#       <td id="T_12766_row6_col1" class="data row6 col1" >33638.50</td>
#       <td id="T_12766_row6_col2" class="data row6 col2" >0.43</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row7_col0" class="data row7 col0" >Q34h: Vrednotenje rezultatov dela</td>
#       <td id="T_12766_row7_col1" class="data row7 col1" >34119.50</td>
#       <td id="T_12766_row7_col2" class="data row7 col2" >0.23</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row8_col0" class="data row8 col0" >Q34i: Podpora vodilnih v klubu</td>
#       <td id="T_12766_row8_col1" class="data row8 col1" >33529.00</td>
#       <td id="T_12766_row8_col2" class="data row8 col2" >0.41</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row9_col0" class="data row9 col0" >Q34j: Dolgoročnost pogodbe o zaposlitvi</td>
#       <td id="T_12766_row9_col1" class="data row9 col1" >33307.00</td>
#       <td id="T_12766_row9_col2" class="data row9 col2" >0.26</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row10_col0" class="data row10 col0" >Q34k: Izpostavljenost dosežkov v medijih</td>
#       <td id="T_12766_row10_col1" class="data row10 col1" >32118.50</td>
#       <td id="T_12766_row10_col2" class="data row10 col2" >0.84</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row11_col0" class="data row11 col0" >Q34l: Medsebojna komunikacija (trener – vodilni)</td>
#       <td id="T_12766_row11_col1" class="data row11 col1" >32260.00</td>
#       <td id="T_12766_row11_col2" class="data row11 col2" >0.96</td>
#     </tr>
#     <tr>
#       <td id="T_12766_row12_col0" class="data row12 col0" >Q34m: Zasledovanje skupnih ciljev</td>
#       <td id="T_12766_row12_col1" class="data row12 col1" >33149.50</td>
#       <td id="T_12766_row12_col2" class="data row12 col2" >0.57</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Interpretacija:** Iz podatkov lahko sklepamo, da imata skupini statistično značilno različno mnenje glede podpore vodilnih na NZS (***Q23i***) in nenehnega dokazovanja (***Q34d***) kot dejavnik ocene zadovoljstva pri delu.

# %%
q23_table_fi = mann_whitney_results(data=df_field, variable='field', var_condition='športna izobrazba', filt='Q23')
q34_table_fi = mann_whitney_results(data=df_field, variable='field', var_condition='športna izobrazba', filt='Q34')

display(
    q23_table_fi.style
        .set_caption('Q23: Biti zadovoljen s trenerskim poklicem je odvisno od več stvari. Kako ocenjujete naslednje vidike in pogoje vaše poklicne usmeritve? Razlika v področju izobrazbe')\
        .format({col: "{:.2f}" for col in q23_table_fi.select_dtypes(include='number').columns})
        .set_table_styles([
              {'selector': 'caption', 'props': [('font-size', '16px'), 
                                                ('font-weight', 'bold'), 
                                                ('border-bottom', '1px solid black'),
                                                ('width', '100%')]},
              {'selector': 'td', 'props': 'text-align: left;'}
          ])\
          .hide())
display(
    q34_table_fi.style
        .set_caption('Q34: Ocenite dejavnike, ki so za vas pomembni za zadovoljstvo pri delu. Razlika v področju izobrazbe')\
        .format({col: "{:.2f}" for col in q34_table_fi.select_dtypes(include='number').columns})
        .set_table_styles([
              {'selector': 'caption', 'props': [('font-size', '16px'), 
                                                ('font-weight', 'bold'), 
                                                ('border-bottom', '1px solid black'),
                                                ('width', '100%')]},
              {'selector': 'td', 'props': 'text-align: left;'}
          ])\
          .hide())
# Out:
# <style type="text/css">
# #T_f91d6 caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# #T_f91d6 td {
#   text-align: left;
# }
# </style>
# <table id="T_f91d6">
#   <caption>Q23: Biti zadovoljen s trenerskim poklicem je odvisno od več stvari. Kako ocenjujete naslednje vidike in pogoje vaše poklicne usmeritve? Razlika v področju izobrazbe</caption>
#   <thead>
#     <tr>
#       <th id="T_f91d6_level0_col0" class="col_heading level0 col0" >Statement</th>
#       <th id="T_f91d6_level0_col1" class="col_heading level0 col1" >U statistic</th>
#       <th id="T_f91d6_level0_col2" class="col_heading level0 col2" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f91d6_row0_col0" class="data row0 col0" >Q23a: uresničevanje svojih idej v praksi</td>
#       <td id="T_f91d6_row0_col1" class="data row0 col1" >20967.50</td>
#       <td id="T_f91d6_row0_col2" class="data row0 col2" >0.14</td>
#     </tr>
#     <tr>
#       <td id="T_f91d6_row1_col0" class="data row1 col0" >Q23b: možnost raznovrstnega treniranja</td>
#       <td id="T_f91d6_row1_col1" class="data row1 col1" >22309.00</td>
#       <td id="T_f91d6_row1_col2" class="data row1 col2" >0.72</td>
#     </tr>
#     <tr>
#       <td id="T_f91d6_row2_col0" class="data row2 col0" >Q23c: pogoji za trening in tekmovanje</td>
#       <td id="T_f91d6_row2_col1" class="data row2 col1" >22918.00</td>
#       <td id="T_f91d6_row2_col2" class="data row2 col2" >0.80</td>
#     </tr>
#     <tr>
#       <td id="T_f91d6_row3_col0" class="data row3 col0" >Q23d: stiki z drugimi strokovnjaki</td>
#       <td id="T_f91d6_row3_col1" class="data row3 col1" >22048.50</td>
#       <td id="T_f91d6_row3_col2" class="data row3 col2" >0.61</td>
#     </tr>
#     <tr>
#       <td id="T_f91d6_row4_col0" class="data row4 col0" >Q23e: ustvarjalno delo</td>
#       <td id="T_f91d6_row4_col1" class="data row4 col1" >20476.00</td>
#       <td id="T_f91d6_row4_col2" class="data row4 col2" >0.06</td>
#     </tr>
#     <tr>
#       <td id="T_f91d6_row5_col0" class="data row5 col0" >Q23f: rezultatski uspehi</td>
#       <td id="T_f91d6_row5_col1" class="data row5 col1" >23310.00</td>
#       <td id="T_f91d6_row5_col2" class="data row5 col2" >0.62</td>
#     </tr>
#     <tr>
#       <td id="T_f91d6_row6_col0" class="data row6 col0" >Q23g: napredek mladih nogometašev</td>
#       <td id="T_f91d6_row6_col1" class="data row6 col1" >20996.50</td>
#       <td id="T_f91d6_row6_col2" class="data row6 col2" >0.11</td>
#     </tr>
#     <tr>
#       <td id="T_f91d6_row7_col0" class="data row7 col0" >Q23h: podpora vodstvenih struktur v klubu</td>
#       <td id="T_f91d6_row7_col1" class="data row7 col1" >22304.50</td>
#       <td id="T_f91d6_row7_col2" class="data row7 col2" >0.72</td>
#     </tr>
#     <tr>
#       <td id="T_f91d6_row8_col0" class="data row8 col0" >Q23i: Podpora vodilnih na NZS</td>
#       <td id="T_f91d6_row8_col1" class="data row8 col1" >24805.00</td>
#       <td id="T_f91d6_row8_col2" class="data row8 col2" >0.09</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f9f10 caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# #T_f9f10 td {
#   text-align: left;
# }
# </style>
# <table id="T_f9f10">
#   <caption>Q34: Ocenite dejavnike, ki so za vas pomembni za zadovoljstvo pri delu. Razlika v področju izobrazbe</caption>
#   <thead>
#     <tr>
#       <th id="T_f9f10_level0_col0" class="col_heading level0 col0" >Statement</th>
#       <th id="T_f9f10_level0_col1" class="col_heading level0 col1" >U statistic</th>
#       <th id="T_f9f10_level0_col2" class="col_heading level0 col2" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f9f10_row0_col0" class="data row0 col0" >Q34a: Pogoji dela</td>
#       <td id="T_f9f10_row0_col1" class="data row0 col1" >23497.00</td>
#       <td id="T_f9f10_row0_col2" class="data row0 col2" >0.34</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row1_col0" class="data row1 col0" >Q34b: Redno plačilo za opravljeno delo</td>
#       <td id="T_f9f10_row1_col1" class="data row1 col1" >22424.00</td>
#       <td id="T_f9f10_row1_col2" class="data row1 col2" >0.94</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row2_col0" class="data row2 col0" >Q34c: Možnosti napredovanja</td>
#       <td id="T_f9f10_row2_col1" class="data row2 col1" >22406.00</td>
#       <td id="T_f9f10_row2_col2" class="data row2 col2" >0.90</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row3_col0" class="data row3 col0" >Q34d: Nenehno dokazovanje</td>
#       <td id="T_f9f10_row3_col1" class="data row3 col1" >23147.00</td>
#       <td id="T_f9f10_row3_col2" class="data row3 col2" >0.54</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row4_col0" class="data row4 col0" >Q34e: Količina stresa pri delu</td>
#       <td id="T_f9f10_row4_col1" class="data row4 col1" >20671.00</td>
#       <td id="T_f9f10_row4_col2" class="data row4 col2" >0.17</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row5_col0" class="data row5 col0" >Q34f: Spoštovanje</td>
#       <td id="T_f9f10_row5_col1" class="data row5 col1" >22376.00</td>
#       <td id="T_f9f10_row5_col2" class="data row5 col2" >0.98</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row6_col0" class="data row6 col0" >Q34g: Priznavanje znanja, izkušenj</td>
#       <td id="T_f9f10_row6_col1" class="data row6 col1" >21956.50</td>
#       <td id="T_f9f10_row6_col2" class="data row6 col2" >0.71</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row7_col0" class="data row7 col0" >Q34h: Vrednotenje rezultatov dela</td>
#       <td id="T_f9f10_row7_col1" class="data row7 col1" >22246.50</td>
#       <td id="T_f9f10_row7_col2" class="data row7 col2" >0.94</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row8_col0" class="data row8 col0" >Q34i: Podpora vodilnih v klubu</td>
#       <td id="T_f9f10_row8_col1" class="data row8 col1" >22700.50</td>
#       <td id="T_f9f10_row8_col2" class="data row8 col2" >0.75</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row9_col0" class="data row9 col0" >Q34j: Dolgoročnost pogodbe o zaposlitvi</td>
#       <td id="T_f9f10_row9_col1" class="data row9 col1" >22532.50</td>
#       <td id="T_f9f10_row9_col2" class="data row9 col2" >0.50</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row10_col0" class="data row10 col0" >Q34k: Izpostavljenost dosežkov v medijih</td>
#       <td id="T_f9f10_row10_col1" class="data row10 col1" >23625.00</td>
#       <td id="T_f9f10_row10_col2" class="data row10 col2" >0.17</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row11_col0" class="data row11 col0" >Q34l: Medsebojna komunikacija (trener – vodilni)</td>
#       <td id="T_f9f10_row11_col1" class="data row11 col1" >22731.00</td>
#       <td id="T_f9f10_row11_col2" class="data row11 col2" >0.73</td>
#     </tr>
#     <tr>
#       <td id="T_f9f10_row12_col0" class="data row12 col0" >Q34m: Zasledovanje skupnih ciljev</td>
#       <td id="T_f9f10_row12_col1" class="data row12 col1" >20882.00</td>
#       <td id="T_f9f10_row12_col2" class="data row12 col2" >0.21</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Interpretacija**: Skupini z različnimi področji izobrazbe se mejno statistično značilno razlikujeta v odgovoru ***Q23e*** (ustvarjalnost pri delu), kot dejavniku pri oceni zadovoljstva pri delu. Glede na to, da je p-vrednost testa enaka mejni vrednosti smo se odločili za konzervativnejši pristop in tako poročamo, da med skupinama z različnimi področji izobrazbe ni statistično značilnih razlik v mnenju kateri dejavniki vplivajo na zadovoljstvo pri delu.

# %%
q32_table_ed = mann_whitney_results(data=df_education, variable='education', var_condition='srednja šola ali manj', filt='Q32')
q32_table_fi = mann_whitney_results(data=df_field, variable='field', var_condition='športna izobrazba', filt='Q32')

display(
    q32_table_ed.style
    .set_caption('Q32: Kje so glavni problemi pri delu v vašem klubu? Razlika v stopnji izobrazbe')\
    .format({col: "{:.2f}" for col in q32_table_ed.select_dtypes(include='number').columns})
    .set_table_styles([
              {'selector': 'caption', 'props': [('font-size', '16px'), 
                                                ('font-weight', 'bold'), 
                                                ('border-bottom', '1px solid black'),
                                                ('width', '100%')]},
              {'selector': 'td', 'props': 'text-align: left;'}
          ])\
          .hide())
display(
    q32_table_fi.style
    .set_caption('Q32: Kje so glavni problemi pri delu v vašem klubu? Razlika v področju izobrazbe')\
    .format({col: "{:.2f}" for col in q32_table_fi.select_dtypes(include='number').columns})
    .set_table_styles([
              {'selector': 'caption', 'props': [('font-size', '16px'), 
                                                ('font-weight', 'bold'), 
                                                ('border-bottom', '1px solid black'),
                                                ('width', '100%')]},
              {'selector': 'td', 'props': 'text-align: left;'}
          ])\
          .hide())
# Out:
# <style type="text/css">
# #T_22792 caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# #T_22792 td {
#   text-align: left;
# }
# </style>
# <table id="T_22792">
#   <caption>Q32: Kje so glavni problemi pri delu v vašem klubu? Razlika v stopnji izobrazbe</caption>
#   <thead>
#     <tr>
#       <th id="T_22792_level0_col0" class="col_heading level0 col0" >Statement</th>
#       <th id="T_22792_level0_col1" class="col_heading level0 col1" >U statistic</th>
#       <th id="T_22792_level0_col2" class="col_heading level0 col2" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_22792_row0_col0" class="data row0 col0" >Q32a: Slabi pogoji za treniranje</td>
#       <td id="T_22792_row0_col1" class="data row0 col1" >34286.50</td>
#       <td id="T_22792_row0_col2" class="data row0 col2" >0.12</td>
#     </tr>
#     <tr>
#       <td id="T_22792_row1_col0" class="data row1 col0" >Q32b: Neurejeni medčloveški odnosi</td>
#       <td id="T_22792_row1_col1" class="data row1 col1" >32051.00</td>
#       <td id="T_22792_row1_col2" class="data row1 col2" >0.95</td>
#     </tr>
#     <tr>
#       <td id="T_22792_row2_col0" class="data row2 col0" >Q32c: Premalo nogometašev je pripravljenih za delo</td>
#       <td id="T_22792_row2_col1" class="data row2 col1" >31385.50</td>
#       <td id="T_22792_row2_col2" class="data row2 col2" >0.77</td>
#     </tr>
#     <tr>
#       <td id="T_22792_row3_col0" class="data row3 col0" >Q32d: Slaba organizacija</td>
#       <td id="T_22792_row3_col1" class="data row3 col1" >32060.50</td>
#       <td id="T_22792_row3_col2" class="data row3 col2" >0.89</td>
#     </tr>
#     <tr>
#       <td id="T_22792_row4_col0" class="data row4 col0" >Q32e: Neustrezno razporejena finančna sredstva, preveč v korist članskih moštev, premalo za mlajše kategorije</td>
#       <td id="T_22792_row4_col1" class="data row4 col1" >30666.50</td>
#       <td id="T_22792_row4_col2" class="data row4 col2" >0.63</td>
#     </tr>
#     <tr>
#       <td id="T_22792_row5_col0" class="data row5 col0" >Q32f: Slaba infrastruktura (nogometno igrišče)</td>
#       <td id="T_22792_row5_col1" class="data row5 col1" >32292.00</td>
#       <td id="T_22792_row5_col2" class="data row5 col2" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_22792_row6_col0" class="data row6 col0" >Q32g: Nestrpnost pri doseganju ciljev</td>
#       <td id="T_22792_row6_col1" class="data row6 col1" >33635.50</td>
#       <td id="T_22792_row6_col2" class="data row6 col2" >0.22</td>
#     </tr>
#     <tr>
#       <td id="T_22792_row7_col0" class="data row7 col0" >Q32h: Zanemarjanje razvoja lastnih igralcev</td>
#       <td id="T_22792_row7_col1" class="data row7 col1" >34154.50</td>
#       <td id="T_22792_row7_col2" class="data row7 col2" >0.16</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7e96d caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# #T_7e96d td {
#   text-align: left;
# }
# </style>
# <table id="T_7e96d">
#   <caption>Q32: Kje so glavni problemi pri delu v vašem klubu? Razlika v področju izobrazbe</caption>
#   <thead>
#     <tr>
#       <th id="T_7e96d_level0_col0" class="col_heading level0 col0" >Statement</th>
#       <th id="T_7e96d_level0_col1" class="col_heading level0 col1" >U statistic</th>
#       <th id="T_7e96d_level0_col2" class="col_heading level0 col2" >p-value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7e96d_row0_col0" class="data row0 col0" >Q32a: Slabi pogoji za treniranje</td>
#       <td id="T_7e96d_row0_col1" class="data row0 col1" >24338.00</td>
#       <td id="T_7e96d_row0_col2" class="data row0 col2" >0.07</td>
#     </tr>
#     <tr>
#       <td id="T_7e96d_row1_col0" class="data row1 col0" >Q32b: Neurejeni medčloveški odnosi</td>
#       <td id="T_7e96d_row1_col1" class="data row1 col1" >21822.00</td>
#       <td id="T_7e96d_row1_col2" class="data row1 col2" >0.81</td>
#     </tr>
#     <tr>
#       <td id="T_7e96d_row2_col0" class="data row2 col0" >Q32c: Premalo nogometašev je pripravljenih za delo</td>
#       <td id="T_7e96d_row2_col1" class="data row2 col1" >22876.00</td>
#       <td id="T_7e96d_row2_col2" class="data row2 col2" >0.51</td>
#     </tr>
#     <tr>
#       <td id="T_7e96d_row3_col0" class="data row3 col0" >Q32d: Slaba organizacija</td>
#       <td id="T_7e96d_row3_col1" class="data row3 col1" >21827.00</td>
#       <td id="T_7e96d_row3_col2" class="data row3 col2" >0.81</td>
#     </tr>
#     <tr>
#       <td id="T_7e96d_row4_col0" class="data row4 col0" >Q32e: Neustrezno razporejena finančna sredstva, preveč v korist članskih moštev, premalo za mlajše kategorije</td>
#       <td id="T_7e96d_row4_col1" class="data row4 col1" >21796.00</td>
#       <td id="T_7e96d_row4_col2" class="data row4 col2" >0.97</td>
#     </tr>
#     <tr>
#       <td id="T_7e96d_row5_col0" class="data row5 col0" >Q32f: Slaba infrastruktura (nogometno igrišče)</td>
#       <td id="T_7e96d_row5_col1" class="data row5 col1" >23548.50</td>
#       <td id="T_7e96d_row5_col2" class="data row5 col2" >0.21</td>
#     </tr>
#     <tr>
#       <td id="T_7e96d_row6_col0" class="data row6 col0" >Q32g: Nestrpnost pri doseganju ciljev</td>
#       <td id="T_7e96d_row6_col1" class="data row6 col1" >21785.00</td>
#       <td id="T_7e96d_row6_col2" class="data row6 col2" >0.87</td>
#     </tr>
#     <tr>
#       <td id="T_7e96d_row7_col0" class="data row7 col0" >Q32h: Zanemarjanje razvoja lastnih igralcev</td>
#       <td id="T_7e96d_row7_col1" class="data row7 col1" >21729.50</td>
#       <td id="T_7e96d_row7_col2" class="data row7 col2" >0.75</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Intepretacija:** Iz opravljenih statističnih testov je razvidno, da med skupinama ni razlik o mnenju, kaj so glavni problemi v klubu.
