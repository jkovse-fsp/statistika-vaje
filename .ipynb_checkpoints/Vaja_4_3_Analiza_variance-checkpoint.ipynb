# %% [markdown]
# ## Poročilo vaja 4.3
# #### Analiza variance: vpliv treninga na VO2max

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import pingouin as pg
from statsmodels.stats.anova import AnovaRM

path = os.getcwd()
df = pd.read_spss(os.path.join(path, 'data\\vo2max-anova-repeated-2grps-gen.sav'))
df.skupina = pd.Categorical(df.skupina.map({1: '1', 2: '2'}))
df = df.rename(columns={'VO2max1': 'week 00',
                   'VO2max2': 'week 05',
                   'VO2max3': 'week 10',
                   'VO2max4': 'week 15',
                   'VO2max5': 'week 20',
                   'skupina': 'group'
                  })
df.head()
time = ['week 00', 'week 05', 'week 10', 'week 15', 'week 20']

# %%
df_pivot = df.pivot_table(
    values= time,
    index='group',
    aggfunc={'count','mean', 'std', 'var'},
    observed=True
)
styled_columns = df_pivot.columns.to_list()
styles_h = [
    {'selector': f'th.col{i}', 'props': [('border-right', '1px solid gray')]}
    for i in range(len(styled_columns))
]
n_cols = len(df_pivot.columns)

styles_c = [
    {'selector': f'td.col{i}', 'props': [('border-right', '1px solid gray')]}
    for i in range(n_cols)
]

display(df_pivot.style
        .set_caption('Table 1: Descriptive statistics')
        .set_table_styles([
            {'selector': 'caption', 'props': [
                ('font-size', '16px'),
                ('font-weight', 'bold'),
                ('border-bottom', '1px solid black'),
                ('width', '100%')
            ]},
            {'selector': 'td', 'props': [('text-align', 'left')]}
        ] + styles_h + styles_c)
        .format(precision=2)
)
# Out:
# <style type="text/css">
# #T_631ac caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# #T_631ac td {
#   text-align: left;
# }
# #T_631ac th.col0 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col1 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col2 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col3 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col4 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col5 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col6 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col7 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col8 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col9 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col10 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col11 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col12 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col13 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col14 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col15 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col16 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col17 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col18 {
#   border-right: 1px solid gray;
# }
# #T_631ac th.col19 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col0 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col1 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col2 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col3 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col4 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col5 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col6 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col7 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col8 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col9 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col10 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col11 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col12 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col13 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col14 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col15 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col16 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col17 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col18 {
#   border-right: 1px solid gray;
# }
# #T_631ac td.col19 {
#   border-right: 1px solid gray;
# }
# </style>
# <table id="T_631ac">
#   <caption>Table 1: Descriptive statistics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_631ac_level0_col0" class="col_heading level0 col0" colspan="4">week 00</th>
#       <th id="T_631ac_level0_col4" class="col_heading level0 col4" colspan="4">week 05</th>
#       <th id="T_631ac_level0_col8" class="col_heading level0 col8" colspan="4">week 10</th>
#       <th id="T_631ac_level0_col12" class="col_heading level0 col12" colspan="4">week 15</th>
#       <th id="T_631ac_level0_col16" class="col_heading level0 col16" colspan="4">week 20</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_631ac_level1_col0" class="col_heading level1 col0" >count</th>
#       <th id="T_631ac_level1_col1" class="col_heading level1 col1" >mean</th>
#       <th id="T_631ac_level1_col2" class="col_heading level1 col2" >std</th>
#       <th id="T_631ac_level1_col3" class="col_heading level1 col3" >var</th>
#       <th id="T_631ac_level1_col4" class="col_heading level1 col4" >count</th>
#       <th id="T_631ac_level1_col5" class="col_heading level1 col5" >mean</th>
#       <th id="T_631ac_level1_col6" class="col_heading level1 col6" >std</th>
#       <th id="T_631ac_level1_col7" class="col_heading level1 col7" >var</th>
#       <th id="T_631ac_level1_col8" class="col_heading level1 col8" >count</th>
#       <th id="T_631ac_level1_col9" class="col_heading level1 col9" >mean</th>
#       <th id="T_631ac_level1_col10" class="col_heading level1 col10" >std</th>
#       <th id="T_631ac_level1_col11" class="col_heading level1 col11" >var</th>
#       <th id="T_631ac_level1_col12" class="col_heading level1 col12" >count</th>
#       <th id="T_631ac_level1_col13" class="col_heading level1 col13" >mean</th>
#       <th id="T_631ac_level1_col14" class="col_heading level1 col14" >std</th>
#       <th id="T_631ac_level1_col15" class="col_heading level1 col15" >var</th>
#       <th id="T_631ac_level1_col16" class="col_heading level1 col16" >count</th>
#       <th id="T_631ac_level1_col17" class="col_heading level1 col17" >mean</th>
#       <th id="T_631ac_level1_col18" class="col_heading level1 col18" >std</th>
#       <th id="T_631ac_level1_col19" class="col_heading level1 col19" >var</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_631ac_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_631ac_row0_col0" class="data row0 col0" >21</td>
#       <td id="T_631ac_row0_col1" class="data row0 col1" >31.45</td>
#       <td id="T_631ac_row0_col2" class="data row0 col2" >4.94</td>
#       <td id="T_631ac_row0_col3" class="data row0 col3" >24.42</td>
#       <td id="T_631ac_row0_col4" class="data row0 col4" >21</td>
#       <td id="T_631ac_row0_col5" class="data row0 col5" >31.45</td>
#       <td id="T_631ac_row0_col6" class="data row0 col6" >4.58</td>
#       <td id="T_631ac_row0_col7" class="data row0 col7" >21.00</td>
#       <td id="T_631ac_row0_col8" class="data row0 col8" >21</td>
#       <td id="T_631ac_row0_col9" class="data row0 col9" >34.60</td>
#       <td id="T_631ac_row0_col10" class="data row0 col10" >6.60</td>
#       <td id="T_631ac_row0_col11" class="data row0 col11" >43.57</td>
#       <td id="T_631ac_row0_col12" class="data row0 col12" >21</td>
#       <td id="T_631ac_row0_col13" class="data row0 col13" >38.51</td>
#       <td id="T_631ac_row0_col14" class="data row0 col14" >9.45</td>
#       <td id="T_631ac_row0_col15" class="data row0 col15" >89.31</td>
#       <td id="T_631ac_row0_col16" class="data row0 col16" >21</td>
#       <td id="T_631ac_row0_col17" class="data row0 col17" >41.66</td>
#       <td id="T_631ac_row0_col18" class="data row0 col18" >12.19</td>
#       <td id="T_631ac_row0_col19" class="data row0 col19" >148.65</td>
#     </tr>
#     <tr>
#       <th id="T_631ac_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_631ac_row1_col0" class="data row1 col0" >43</td>
#       <td id="T_631ac_row1_col1" class="data row1 col1" >31.43</td>
#       <td id="T_631ac_row1_col2" class="data row1 col2" >4.76</td>
#       <td id="T_631ac_row1_col3" class="data row1 col3" >22.65</td>
#       <td id="T_631ac_row1_col4" class="data row1 col4" >43</td>
#       <td id="T_631ac_row1_col5" class="data row1 col5" >31.35</td>
#       <td id="T_631ac_row1_col6" class="data row1 col6" >6.14</td>
#       <td id="T_631ac_row1_col7" class="data row1 col7" >37.72</td>
#       <td id="T_631ac_row1_col8" class="data row1 col8" >43</td>
#       <td id="T_631ac_row1_col9" class="data row1 col9" >31.90</td>
#       <td id="T_631ac_row1_col10" class="data row1 col10" >5.72</td>
#       <td id="T_631ac_row1_col11" class="data row1 col11" >32.73</td>
#       <td id="T_631ac_row1_col12" class="data row1 col12" >43</td>
#       <td id="T_631ac_row1_col13" class="data row1 col13" >32.54</td>
#       <td

# %%
grouped_median = df.groupby('group', observed=True)[time].mean()

grouped_median = grouped_median.T

grouped_median.plot(kind='line', marker='o')
plt.title('Mean VO2max by group')
plt.xlabel('Time [weeks]')
plt.ylabel('VO2max [mL/kg*min]')
plt.legend(title='Group')
plt.tight_layout()
plt.show()

# %% [markdown]
# Iz opisne statistike opazimo, da obstajajo razlike med vrednostmi VO2max med skupinama, prav tako pa obstajajo razlike med vrednostmi VO2max znotraj posamezne skupine. Dokaz, o tem ali je razlika med VO2max znotraj skupine statistično značilna bomo dokazali z ANOVO ponavljajočih meritev.
#
# **HO:** Med meritvami VO2max v različnih tednih ne obstajajo statistično značilne razlike.
#
# **H1:** Med meritvami V=2max v različnih tednih obstajajo statistično značilne razlike.

# %%
df['subject'] = df.index

df_long = pd.melt(df,
                  id_vars=['subject', 'group'],
                  value_vars=time,
                  var_name='week',
                  value_name='vo2max')


df_long['week'] = df_long['week'].str.extract(r'(\d)').astype(int)
g_1 = df_long[df_long['group'] == '1'].drop(columns='group')
g_2 = df_long[df_long['group'] == '2'].drop(columns='group')

aov1 = pg.rm_anova(data=g_1, dv='vo2max', within='week', subject='subject', correction=True, detailed=True)
aov2 = pg.rm_anova(data=g_2, dv='vo2max', within='week', subject='subject', correction=True, detailed=True)
anova_rm = pg.rm_anova(data=df_long, dv='vo2max', within='week', subject='subject', correction=True, detailed=True)

display(aov1.style.set_caption('Repeated measures ANOVA: group 1').set_table_styles([
            {'selector': 'caption', 'props': [
                ('font-size', '16px'),
                ('font-weight', 'bold'),
                ('border-bottom', '1px solid black'),
                ('width', '100%')
            ]}]))
display(aov2.style.set_caption('Repeated measures ANOVA: group 2').set_table_styles([
            {'selector': 'caption', 'props': [
                ('font-size', '16px'),
                ('font-weight', 'bold'),
                ('border-bottom', '1px solid black'),
                ('width', '100%')
            ]}]))
display(anova_rm.style.set_caption('Repeated measures ANOVA: between groups').set_table_styles([
            {'selector': 'caption', 'props': [
                ('font-size', '16px'),
                ('font-weight', 'bold'),
                ('border-bottom', '1px solid black'),
                ('width', '100%')
            ]}]))
# Out:
# <style type="text/css">
# #T_c08b7 caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# </style>
# <table id="T_c08b7">
#   <caption>Repeated measures ANOVA: group 1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c08b7_level0_col0" class="col_heading level0 col0" >Source</th>
#       <th id="T_c08b7_level0_col1" class="col_heading level0 col1" >SS</th>
#       <th id="T_c08b7_level0_col2" class="col_heading level0 col2" >DF</th>
#       <th id="T_c08b7_level0_col3" class="col_heading level0 col3" >MS</th>
#       <th id="T_c08b7_level0_col4" class="col_heading level0 col4" >F</th>
#       <th id="T_c08b7_level0_col5" class="col_heading level0 col5" >p-unc</th>
#       <th id="T_c08b7_level0_col6" class="col_heading level0 col6" >p-GG-corr</th>
#       <th id="T_c08b7_level0_col7" class="col_heading level0 col7" >ng2</th>
#       <th id="T_c08b7_level0_col8" class="col_heading level0 col8" >eps</th>
#       <th id="T_c08b7_level0_col9" class="col_heading level0 col9" >sphericity</th>
#       <th id="T_c08b7_level0_col10" class="col_heading level0 col10" >W-spher</th>
#       <th id="T_c08b7_level0_col11" class="col_heading level0 col11" >p-spher</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c08b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c08b7_row0_col0" class="data row0 col0" >week</td>
#       <td id="T_c08b7_row0_col1" class="data row0 col1" >1094.256822</td>
#       <td id="T_c08b7_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_c08b7_row0_col3" class="data row0 col3" >547.128411</td>
#       <td id="T_c08b7_row0_col4" class="data row0 col4" >12.684215</td>
#       <td id="T_c08b7_row0_col5" class="data row0 col5" >0.000054</td>
#       <td id="T_c08b7_row0_col6" class="data row0 col6" >0.000443</td>
#       <td id="T_c08b7_row0_col7" class="data row0 col7" >0.199737</td>
#       <td id="T_c08b7_row0_col8" class="data row0 col8" >0.705662</td>
#       <td id="T_c08b7_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_c08b7_row0_col10" class="data row0 col10" >0.582892</td>
#       <td id="T_c08b7_row0_col11" class="data row0 col11" >0.005930</td>
#     </tr>
#     <tr>
#       <th id="T_c08b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c08b7_row1_col0" class="data row1 col0" >Error</td>
#       <td id="T_c08b7_row1_col1" class="data row1 col1" >1725.383644</td>
#       <td id="T_c08b7_row1_col2" class="data row1 col2" >40</td>
#       <td id="T_c08b7_row1_col3" class="data row1 col3" >43.134591</td>
#       <td id="T_c08b7_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_c08b7_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_c08b7_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_c08b7_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_c08b7_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_c08b7_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_c08b7_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_c08b7_row1_col11" class="data row1 col11" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a49ea caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# </style>
# <table id="T_a49ea">
#   <caption>Repeated measures ANOVA: group 2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a49ea_level0_col0" class="col_heading level0 col0" >Source</th>
#       <th id="T_a49ea_level0_col1" class="col_heading level0 col1" >SS</th>
#       <th id="T_a49ea_level0_col2" class="col_heading level0 col2" >DF</th>
#       <th id="T_a49ea_level0_col3" class="col_heading level0 col3" >MS</th>
#       <th id="T_a49ea_level0_col4" class="col_heading level0 col4" >F</th>
#       <th id="T_a49ea_level0_col5" class="col_heading level0 col5" >p-unc</th>
#       <th id="T_a49ea_level0_col6" class="col_heading level0 col6" >p-GG-corr</th>
#       <th id="T_a49ea_level0_col7" class="col_heading level0 col7" >ng2</th>
#       <th id="T_a49ea_level0_col8" class="col_heading level0 col8" >eps</th>
#       <th id="T_a49ea_level0_col9" class="col_heading level0 col9" >sphericity</th>
#       <th id="T_a49ea_level0_col10" class="col_heading level0 col10" >W-spher</th>
#       <th id="T_a49ea_level0_col11" class="col_heading level0 col11" >p-spher</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a49ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a49ea_row0_col0" class="data row0 col0" >week</td>
#       <td id="T_a49ea_row0_col1" class="data row0 col1" >156.936634</td>
#       <td id="T_a49ea_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_a49ea_row0_col3" class="data row0 col3" >78.468317</td>
#       <td id="T_a49ea_row0_col4" class="data row0 col4" >8.221268</td>
#       <td id="T_a49ea_row0_col5" class="data row0 col5" >0.000549</td>
#       <td id="T_a49ea_row0_col6" class="data row0 col6" >0.002993</td>
#       <td id="T_a49ea_row0_col7" class="data row0 col7" >0.041717</td>
#       <td id="T_a49ea_row0_col8" class="data row0 col8" >0.654801</td>
#       <td id="T_a49ea_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_a49ea_row0_col10" class="data row0 col10" >0.472818</td>
#       <td id="T_a49ea_row0_col11" class="data row0 col11" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a49ea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a49ea_row1_col0" class="data row1 col0" >Error</td>
#       <td id="T_a49ea_row1_col1" class="data row1 col1" >801.742366</td>
#       <td id="T_a49ea_row1_col2" class="data row1 col2" >84</td>
#       <td id="T_a49ea_row1_col3" class="data row1 col3" >9.544552</td>
#       <td id="T_a49ea_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a49ea_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_a49ea_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_a49ea_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_a49ea_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_a49ea_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_a49ea_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_a49ea_row1_col11" class="data row1 col11" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cd6c7 caption {
#   font-size: 16px;
#   font-weight: bold;
#   border-bottom: 1px solid black;
#   width: 100%;
# }
# </style>
# <table id="T_cd6c7">
#   <caption>Repeated measures ANOVA: between groups</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd6c7_level0_col0" class="col_heading level0 col0" >Source</th>
#       <th id="T_cd6c7_level0_col1" class="col_heading level0 col1" >SS</th>
#       <th id="T_cd6c7_level0_col2" class="col_heading level0 col2" >DF</th>
#       <th id="T_cd6c7_level0_col3" class="col_heading level0 col3" >MS</th>
#       <th id="T_cd6c7_level0_col4" class="col_heading level0 col4" >F</th>
#       <th id="T_cd6c7_level0_col5" class="col_heading level0 col5" >p-unc</th>
#       <th id="T_cd6c7_level0_col6" class="col_heading level0 col6" >p-GG-corr</th>
#       <th id="T_cd6c7_level0_col7" class="col_heading level0 col7" >ng2</th>
#       <th id="T_cd6c7_level0_col8" class="col_heading level0 col8" >eps</th>
#       <th id="T_cd6c7_level0_col9" class="col_heading level0 col9" >sphericity</th>
#       <th id="T_cd6c7_level0_col10" class="col_heading level0 col10" >W-spher</th>
#       <th id="T_cd6c7_level0_col11" class="col_heading level0 col11" >p-spher</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd6c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd6c7_row0_col0" class="data row0 col0" >week</td>
#       <td id="T_cd6c7_row0_col1" class="data row0 col1" >844.936484</td>
#       <td id="T_cd6c7_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_cd6c7_row0_col3" class="data row0 col3" >422.468242</td>
#       <td id="T_cd6c7_row0_col4" class="data row0 col4" >18.146624</td>
#       <td id="T_cd6c7_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_cd6c7_row0_col6" class="data row0 col6" >0.000007</td>
#       <td id="T_cd6c7_row0_col7" class="data row0 col7" >0.085166</td>
#       <td id="T_cd6c7_row0_col8" class="data row0 col8" >0.681906</td>
#       <td id="T_cd6c7_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_cd6c7_row0_col10" class="data row0 col10" >0.533523</td>
#       <td id="T_cd6c7_row0_col11" class="data row0 col11" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_cd6c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd6c7_row1_col0" class="data row1 col0" >Error</td>
#       <td id="T_cd6c7_row1_col1" class="data row1 col1" >2933.382982</td>
#       <td id="T_cd6c7_row1_col2" class="data row1 col2" >126</td>
#       <td id="T_cd6c7_row1_col3" class="data row1 col3" >23.280817</td>
#       <td id="T_cd6c7_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_cd6c7_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_cd6c7_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_cd6c7_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_cd6c7_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_cd6c7_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_cd6c7_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_cd6c7_row1_col11" class="data row1 col11" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Interpretacija:** Iz rezultatov v tabeli lahko vidimo, da je sferičnost v primeru obeh skupin kršena, zato smo popravili p vrednost ANOVE ponovljivih meritev z Greenhouse-Geisser popravkom. Opazimo, da čas treninga statistično značilno vpliva na vrednosti VO2max pri obeh skupinah, kot tudi, da je statistično značilna razlika med vrednostmi VO2max med skupinama. Iz zgornjega grafa lahko razberemo, da je napredek pri skupini 1 večji kot pri skupini 2. Opravimo tudi post-hoc analizo, da ugotovimo v katerem tednu se začne kazati statistično značilna razlika v vrednostih VO2max za prvo skupino in za drugo skupino.

# %%
posthoc1 = pg.pairwise_tests(data=g_1, dv='vo2max', within='week', subject='subject', parametric=True, padjust='none')
display(posthoc1)
posthoc2 = pg.pairwise_tests(data=g_2, dv='vo2max', within='week', subject='subject', parametric=True, padjust='none')
display(posthoc2)
# Out:
#   Contrast  A  B  Paired  Parametric         T   dof alternative     p-unc  \
# 0     week  0  1    True        True -3.974314  20.0   two-sided  0.000747
# 1     week  0  2    True        True -4.100194  20.0   two-sided  0.000557
# 2     week  1  2    True        True -2.413274  20.0   two-sided  0.025525
#
#      BF10    hedges
# 0  46.671 -0.842831
# 1  60.408 -1.094519
# 2   2.334 -0.500506
#   Contrast  A  B  Paired  Parametric         T   dof alternative     p-unc  \
# 0     week  0  1    True        True -2.094090  42.0   two-sided  0.042326
# 1     week  0  2    True        True -3.126264  42.0   two-sided  0.003209
# 2     week  1  2    True        True -2.668415  42.0   two-sided  0.010784
#
#      BF10    hedges
# 0   1.189 -0.168390
# 1  10.644 -0.463496
# 2   3.724 -0.327008
